# %% [markdown]
# # **Tugas Besar I Probabilitas dan Statistika Semester II Tahun Akademik 2020/2021**
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as s
import seaborn as sns
alpha = 0.05
colnames = ['id', 'daerah', 'sumbu utama', 'sumbu kecil', 'keunikan', 'area bulatan', 'diameter', 'kadar air', 'keliling', 'bulatan', 'ransum', 'kelas']
url = 'https://drive.google.com/file/d/1z0EyNb2c5PD-ECNgsS_6f7KV6bm2ya10/view?usp=sharing' # copy of original dataset, in personal drive
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
g = pd.read_csv(path, header=None)
g.columns = colnames
gandum = g[g.columns[1:11]] #gstripped

# %% [markdown]
# ##1.  *Descriptive Statistics*

# %%
gandum.describe()
# Out:
#             daerah  sumbu utama  sumbu kecil    keunikan  area bulatan  \
# count   500.000000   500.000000   500.000000  500.000000    500.000000
# mean   4801.246000   116.045171    53.715246    0.878764   4937.048000
# std     986.395491    18.282626     4.071075    0.036586   1011.696255
# min    2522.000000    74.133114    39.906517    0.719916   2579.000000
# 25%    4042.750000   104.116098    51.193576    0.863676   4170.250000
# 50%    4735.000000   115.405140    53.731199    0.890045   4857.000000
# 75%    5495.500000   129.046792    56.325158    0.907578   5654.250000
# max    7453.000000   227.928583    68.977700    0.914001   7720.000000
#
#          diameter   kadar air    keliling     bulatan      ransum
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    77.771158    0.648372  281.479722    0.761737    2.150915
# std      8.056867    0.094367   37.335402    0.061702    0.249767
# min     56.666658    0.409927  197.015000    0.174590    1.440796
# 25%     71.745308    0.572632  255.883000    0.731991    1.983939
# 50%     77.645277    0.626117  280.045500    0.761288    2.193599
# 75%     83.648598    0.726633  306.062500    0.796361    2.381612
# max     97.413830    0.878899  488.837000    0.904748    2.464809

# %% [markdown]
# Mean

# %%
gandum.mean() #mean
# Out:
# daerah          4801.246000
# sumbu utama      116.045171
# sumbu kecil       53.715246
# keunikan           0.878764
# area bulatan    4937.048000
# diameter          77.771158
# kadar air          0.648372
# keliling         281.479722
# bulatan            0.761737
# ransum             2.150915
# dtype: float64

# %% [markdown]
# Median

# %%
gandum.median() #median
# Out:
# daerah          4735.000000
# sumbu utama      115.405140
# sumbu kecil       53.731199
# keunikan           0.890045
# area bulatan    4857.000000
# diameter          77.645277
# kadar air          0.626117
# keliling         280.045500
# bulatan            0.761288
# ransum             2.193599
# dtype: float64

# %% [markdown]
# Modus

# %%
for i in colnames:
  if i != 'id' and i != 'kelas':
    mod = gandum[i].mode()
    print("Modus " + i + ": ", end="")
    for j in range(len(mod)):
      if j != len(mod) -1:
        print(mod[j], end= ", ")
      else:
        print(mod[j])
# Out:
# 900231555, 0.900709775, 0.900816877, 0.900824698, 0.901454467, 0.901459146, 0.9017719, 0.901923974, 0.901952409, 0.901991908, 0.90205221, 0.902073926, 0.902219665, 0.902261482, 0.902315363, 0.90233874, 0.902460367, 0.902465603, 0.902513877, 0.902748339, 0.902862282, 0.903020474, 0.903059593, 0.903079379, 0.90309414, 0.903233579, 0.903241493, 0.90351695, 0.903578014, 0.903675005, 0.903707581, 0.903813708, 0.903873539, 0.903934354, 0
263187001, 2.264349408, 2.266611124, 2.267386283, 2.267430923, 2.267500333, 2.267748924, 2.267809234, 2.267963643, 2.269278355, 2.269768294, 2.274378701, 2.275694235, 2.275694736, 2.277530842, 2.277961715, 2.278028913, 2.280405651, 2.289417954, 2.290839165, 2.290891123, 2.292288889, 2.293674225, 2.29600804, 2.296663622, 2.296678136, 2.301912694, 2.303090322, 2.30 ...

# %% [markdown]
# Standar Deviasi

# %%
gandum.std() #standar deviasi
# Out:
# daerah           986.395491
# sumbu utama       18.282626
# sumbu kecil        4.071075
# keunikan           0.036586
# area bulatan    1011.696255
# diameter           8.056867
# kadar air          0.094367
# keliling          37.335402
# bulatan            0.061702
# ransum             0.249767
# dtype: float64

# %% [markdown]
# Variansi

# %%
gandum.var() # variansi
# Out:
# daerah          9.729761e+05
# sumbu utama     3.342544e+02
# sumbu kecil     1.657365e+01
# keunikan        1.338528e-03
# area bulatan    1.023529e+06
# diameter        6.491311e+01
# kadar air       8.905149e-03
# keliling        1.393932e+03
# bulatan         3.807194e-03
# ransum          6.238350e-02
# dtype: float64

# %% [markdown]
# Range

# %%
gandum.max() - gandum.min() #range
# Out:
# daerah          4931.000000
# sumbu utama      153.795469
# sumbu kecil       29.071182
# keunikan           0.194085
# area bulatan    5141.000000
# diameter          40.747172
# kadar air          0.468972
# keliling         291.822000
# bulatan            0.730158
# ransum             1.024013
# dtype: float64

# %% [markdown]
# Min

# %%
gandum.min() #min
# Out:
# daerah          2522.000000
# sumbu utama       74.133114
# sumbu kecil       39.906517
# keunikan           0.719916
# area bulatan    2579.000000
# diameter          56.666658
# kadar air          0.409927
# keliling         197.015000
# bulatan            0.174590
# ransum             1.440796
# dtype: float64

# %% [markdown]
# Max

# %%
gandum.max() #max
# Out:
# daerah          7453.000000
# sumbu utama      227.928583
# sumbu kecil       68.977700
# keunikan           0.914001
# area bulatan    7720.000000
# diameter          97.413830
# kadar air          0.878899
# keliling         488.837000
# bulatan            0.904748
# ransum             2.464809
# dtype: float64

# %% [markdown]
# Kuartil

# %%
gandum.quantile([0.25,0.5,0.75]) #kuartil (quantil 0.25, 0.5, 0.75)
# Out:
#        daerah  sumbu utama  sumbu kecil  keunikan  area bulatan   diameter  \
# 0.25  4042.75   104.116098    51.193576  0.863676       4170.25  71.745308
# 0.50  4735.00   115.405140    53.731199  0.890045       4857.00  77.645277
# 0.75  5495.50   129.046792    56.325158  0.907578       5654.25  83.648598
#
#       kadar air  keliling   bulatan    ransum
# 0.25   0.572632  255.8830  0.731991  1.983939
# 0.50   0.626117  280.0455  0.761288  2.193599
# 0.75   0.726633  306.0625  0.796361  2.381612

# %% [markdown]
# IQR

# %%
gandum.quantile(0.75) - gandum.quantile(0.25) #IQR
# Out:
# daerah          1452.750000
# sumbu utama       24.930694
# sumbu kecil        5.131582
# keunikan           0.043902
# area bulatan    1484.000000
# diameter          11.903290
# kadar air          0.154001
# keliling          50.179500
# bulatan            0.064370
# ransum             0.397673
# dtype: float64

# %% [markdown]
# Skewness

# %%
gandum.skew()
# Out:
# daerah          0.238144
# sumbu utama     0.761529
# sumbu kecil    -0.010828
# keunikan       -1.623472
# area bulatan    0.257560
# diameter        0.002725
# kadar air       0.493661
# keliling        0.733627
# bulatan        -3.599237
# ransum         -0.658188
# dtype: float64

# %% [markdown]
# Kurtosis

# %%
gandum.kurtosis()
# Out:
# daerah          -0.434631
# sumbu utama      4.330534
# sumbu kecil      0.475568
# keunikan         2.917256
# area bulatan    -0.409685
# diameter        -0.466455
# kadar air       -0.740326
# keliling         2.272685
# bulatan         29.975096
# ransum          -0.428656
# dtype: float64

# %% [markdown]
# ## 2. Visualisasi

# %% [markdown]
# Boxplot

# %%
fig, axes = plt.subplots(nrows = 3, ncols=4, figsize=(14,14))

row = 0
for i, col in enumerate(gandum.columns):
  gandum.boxplot(column=col, ax=axes[row, i%4])
  if i % 4 == 3:
    row += 1
plt.show()

# %%
df = pd.DataFrame(data = gandum, columns = ['daerah'])
boxplot = df.boxplot(column = ['daerah'])

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu utama'])
boxplot = df.boxplot(column = ['sumbu utama'])

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu kecil'])
boxplot = df.boxplot(column = ['sumbu kecil'])

# %%
df = pd.DataFrame(data = gandum, columns = ['keunikan'])
boxplot = df.boxplot(column = ['keunikan'])

# %%
df = pd.DataFrame(data = gandum, columns = ['area bulatan'])
boxplot = df.boxplot(column = ['area bulatan'])

# %%
df = pd.DataFrame(data = gandum, columns = ['diameter'])
boxplot = df.boxplot(column = ['diameter'])

# %%
df = pd.DataFrame(data = gandum, columns = ['kadar air'])
boxplot = df.boxplot(column = ['kadar air'])

# %%
df = pd.DataFrame(data = gandum, columns = ['keliling'])
boxplot = df.boxplot(column = ['keliling'])

# %%
df = pd.DataFrame(data = gandum, columns = ['bulatan'])
boxplot = df.boxplot(column = ['bulatan'])

# %%
df = pd.DataFrame(data = gandum, columns = ['ransum'])
boxplot = df.boxplot(column = ['ransum'])

# %% [markdown]
# Histogram

# %%
gandum.hist(figsize=(20, 20), edgecolor='black')
# Out:
# C:\Users\Girvin Junod\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'daerah'}>,
#         <AxesSubplot:title={'center':'sumbu utama'}>,
#         <AxesSubplot:title={'center':'sumbu kecil'}>],
#        [<AxesSubplot:title={'center':'keunikan'}>,
#         <AxesSubplot:title={'center':'area bulatan'}>,
#         <AxesSubplot:title={'center':'diameter'}>],
#        [<AxesSubplot:title={'center':'kadar air'}>,
#         <AxesSubplot:title={'center':'keliling'}>,
#         <AxesSubplot:title={'center':'bulatan'}>],
#        [<AxesSubplot:title={'center':'ransum'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df = pd.DataFrame(data = gandum, columns = ['daerah'])
hist = df.plot.hist(bins = 10, color = '#FF8700', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu utama'])
hist = df.plot.hist(bins = 10, color = '#843795', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu kecil'])
hist = df.plot.hist(bins = 10, color = '#ffe08d', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['keunikan'])
hist = df.plot.hist(bins = 10, color = '#96ceb4', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['area bulatan'])
hist = df.plot.hist(bins = 10, color = '#415786', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['diameter'])
hist = df.plot.hist(bins = 10, color = '#80C6FF', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['kadar air'])
hist = df.plot.hist(bins = 10, color = '#071ACD', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['keliling'])
hist = df.plot.hist(bins = 10, color = '#420420', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['bulatan'])
hist = df.plot.hist(bins = 10, color = '#696969', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['ransum'])
hist = df.plot.hist(bins = 10, color = '#1A1E43', edgecolor='black')

# %% [markdown]
# ## 3. Normality Test

# %% [markdown]
# ### Daerah

# %%
df = pd.DataFrame(data = gandum, columns = ['daerah'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 0.0032707
# Tidak berdistribusi normal

# %%
sns.distplot(gandum['daerah'])
# Out:
# C:\Users\Girvin Junod\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='daerah', ylabel='Density'>

# %% [markdown]
# Penjelasan :

# %% [markdown]
# ### Sumbu Utama

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu utama'])
hist = df.plot.hist(bins = 10, color = '#843795', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu utama'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 9.2362e-12
# Tidak berdistribusi normal

# %% [markdown]
# ### Sumbu Kecil

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu kecil'])
hist = df.plot.hist(bins = 10, color = '#ffe08d', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['sumbu kecil'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 0.423456
# Berdistribusi normal

# %% [markdown]
# ### Keunikan

# %%
df = pd.DataFrame(data = gandum, columns = ['keunikan'])
hist = df.plot.hist(bins = 10, color = '#96ceb4', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['keunikan'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 1.31517e-22
# Tidak berdistribusi normal

# %% [markdown]
# ### AreaBulatan

# %%
df = pd.DataFrame(data = gandum, columns = ['area bulatan'])
hist = df.plot.hist(bins = 10, color = '#415786', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['area bulatan'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 0.00248471
# Tidak berdistribusi normal

# %% [markdown]
# ### Diameter

# %%
df = pd.DataFrame(data = gandum, columns = ['diameter'])
hist = df.plot.hist(bins = 10, color = '#80C6FF', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['diameter'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 0.118345
# Berdistribusi normal

# %% [markdown]
# ### KadarAir

# %%
df = pd.DataFrame(data = gandum, columns = ['kadar air'])
hist = df.plot.hist(bins = 10, color = '#071ACD', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['kadar air'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 1.9595e-12
# Tidak berdistribusi normal

# %% [markdown]
# ###Keliling

# %%
df = pd.DataFrame(data = gandum, columns = ['keliling'])
hist = df.plot.hist(bins = 10, color = '#420420', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['keliling'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 9.72839e-09
# Tidak berdistribusi normal

# %% [markdown]
# ### Bulatan

# %%
df = pd.DataFrame(data = gandum, columns = ['bulatan'])
hist = df.plot.hist(bins = 10, color = '#696969', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['bulatan'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 6.89916e-26
# Tidak berdistribusi normal

# %% [markdown]
# ### Ransum

# %%
df = pd.DataFrame(data = gandum, columns = ['ransum'])
hist = df.plot.hist(bins = 10, color = '#1A1E43', edgecolor='black')

# %%
df = pd.DataFrame(data = gandum, columns = ['ransum'])
#stat, p = s.normaltest(df, axis= 0, nan_policy='omit') D'Agostino
stat, p = s.shapiro(df) #shapiro wilks
print("p = {:g}".format(p))
if p <= alpha:  # null hypothesis: x comes from a normal distribution
    print("Tidak berdistribusi normal")
else:
    print("Berdistribusi normal")
# Out:
# p = 6.24554e-15
# Tidak berdistribusi normal

# %% [markdown]
# # Test Hipotesis 1 Sampel

# %%
import math

def zscore(x, mean, std, n):
  return (x-mean)*math.sqrt(n)/std

# %%
def ptoz(p):
  return s.norm.ppf(p)
def ztop(z):
  return s.norm.cdf(z)

# %% [markdown]
# ##(**A**) Nilai rata-rata Daerah di atas 4700?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu = 4700
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu > 4700
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#    Uji statistik yang digunakan adalah : Uji parameter populasi pengujian rataan satu sampel one tail test variance known
#
#    Daerah kritis : z > zalpha : z > 1.645
#
# 5. Hitung nilai uji statistik

# %%
mean = 4700
rataan = gandum['daerah'].mean()
std = gandum['daerah'].std()
n = gandum['daerah'].count()
z = zscore(rataan, mean, std, n)
p = 1 - ztop(z)
zalpha = ptoz(1-alpha)

# %% [markdown]
# ### 6. Ambil keputusan

# %%
if z > zalpha:
  print("Tolak null hypothesis")
  print("Hipotesis alternatif benar")
  print("Nilai rata-rata Daerah di atas 4700")
else:
  print("Terima null hypothesis")
  print("Hipotesis alternatif salah")
# Out:
# Tolak null hypothesis
# Hipotesis alternatif benar
# Nilai rata-rata Daerah di atas 4700

# %% [markdown]
# ## B) Nilai Rata-rata Sumbu Utama tidak sama dengan 116?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu = 116
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu != 116 (two-tailed test)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik : Uji parameter populasi pengujian rataan satu sampel two tail test variance known
#
#     daerah kritis : z < (-zalpha/2) or z > (zalpha/2)
# 5. Hitung nilai uji statistik

# %%
mean = 116
rataan = gandum['sumbu utama'].mean()
std = gandum['sumbu utama'].std()
n = gandum['sumbu utama'].count()
z = zscore(rataan, mean, std, n)
zalpha = ptoz(alpha/2)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z < zalpha or z > -zalpha:
  print("Null hypothesis ditolak")
else:
  print("Null hypothesis diterima")
  print("Rata-rata sumbu utama sama dengan 116")
# Out:
# Null hypothesis diterima
# Rata-rata sumbu utama sama dengan 116

# %% [markdown]
# ## C) Nilai Rata-rata 20 baris pertama kolom Sumbu Kecil bukan 50?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu = 50
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu != 50 (two-tailed test)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik : Uji parameter populasi pengujian rataan satu sampel two tail test variance known
#
#     daerah kritis : z < (-zalpha/2) or z > (zalpha/2)
#
# 5. Hitung nilai uji statistik

# %%
mean = 50
sampel = gandum['sumbu utama'].head(20)
rataan = sampel.mean()
std = sampel.std()
n = sampel.count()
z = zscore(rataan, mean, std, n)
zalpha = ptoz(alpha/2)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z < zalpha or z > -zalpha:
  print("Null hypothesis ditolak")
  print("Nilai rata-rata 20 baris pertama kolom sumbu kecil bukan 50")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Nilai rata-rata 20 baris pertama kolom sumbu kecil bukan 50

# %% [markdown]
# ## D) Proporsi nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15% ?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : p = 0.15
# 2. Tentukan hipotesis alternatif
#
#     H1 : p != 0.15 (two-tailed test)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji satu parameter populasi  pengujian proporsi satu sampel dengan sample banyak
#
#     Daerah kritis : z > zalpha/2 or z < -zalpha/2
#
# 5. Hitung nilai statistik

# %%
diameter = gandum['diameter'].loc[gandum['diameter'] > 85]
p0 = 0.15 
q0 = 1 - p0
zalpha = ptoz(alpha/2)
n = gandum['diameter'].count()
x = diameter.count()
p1 = x/n

z = (p1-p0) * math.sqrt(n)/ math.sqrt(p0*q0)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z < zalpha or z > -zalpha:
  print("Null hypothesis ditolak")
  print("Nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15%")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15%

# %% [markdown]
# ## E) Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5% ?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : p = 0.05
# 2. Tentukan hipotesis alternatif
#
#     H1 : p < 0.05 (one-tailed test)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji satu parameter populasi pengujian proporsi satu sampel dengan sample banyak one tailed test
#
#     Daerah kritis : z < -zalpha
#
# 5. Hitung nilai uji statistik

# %%
keliling = gandum['keliling'].loc[gandum['keliling'] < 100]
p0 = 0.05 
q0 = 1 - p0
zalpha = ptoz(alpha)
n = gandum['keliling'].count()
x = keliling.count()
p1 = x/n

z = (p1-p0) * math.sqrt(n)/ math.sqrt(p0*q0)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z < -zalpha:
  print("Null hypothesis ditolak")
  print("Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5%")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5%

# %% [markdown]
# # Test Hipotesis 2 Sampel

# %% [markdown]
# ## A) Data kolom AreaBulatan dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama?

# %%
def ztwotestmean(d0, x1, x2, var1, var2, n1, n2):
  return((x1 - x2) - d0)/math.sqrt((var1/n1) + (var2/n2))

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu1 - miu2 = 0
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu1 - miu2 != 0 (two-tailed)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik : two sample two tailed mean test known std
#
#     daerah kritis : z < -zalpha/2 or z > zalpha/2
#
# 5. Hitung nilai uji statistik

# %%
areaBulat = gandum['area bulatan']

d0 = 0

zalpha = ptoz(alpha/2)
bagian1 = areaBulat.head(areaBulat.size // 2)
bagian2 = areaBulat.tail(areaBulat.size // 2)

mean1 = bagian1.mean()
mean2 = bagian2.mean()

var1 = bagian1.var()
var2 = bagian2.var()

z = ztwotestmean(d0, mean1, mean2, var1, var2, bagian1.size, bagian2.size)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z < zalpha or z > -zalpha:
  print("Null hypothesis ditolak")
  print("Rata-rata kedua bagian tidak sama")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Rata-rata kedua bagian tidak sama

# %% [markdown]
# ## B) Data kolom Kadar Air dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.2?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu1 - miu2 = 0.2
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu1 - miu2 > 0.2 (one-tailed)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik : two sample two tailed mean test known std
#
#     Daerah kritis : z > zalpha
#
# 5. Hitung nilai uji statistik

# %%
kadarAir = gandum['kadar air']

d0 = 0.2

zalpha = ptoz(alpha)
bagian1 = kadarAir.head(kadarAir.size // 2)
bagian2 = kadarAir.tail(kadarAir.size // 2)

mean1 = bagian1.mean()
mean2 = bagian2.mean()

var1 = bagian1.var()
var2 = bagian2.var()

z = ztwotestmean(d0, mean1, mean2, var1, var2, bagian1.size, bagian2.size)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z > zalpha:
  print("Null hypothesis ditolak")
else:
  print("Null hypothesis diterima")
  print("Rata-rata bagian awal tidak lebih besar dari pada bagian akhir sebesar 0.2")
# Out:
# Null hypothesis diterima
# Rata-rata bagian awal tidak lebih besar dari pada bagian akhir sebesar 0.2

# %% [markdown]
# ## C) Rata-rata 20 baris pertama kolom Bulatan sama dengan 20 baris terakhirnya?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : miu1 - miu2 = 0
# 2. Tentukan hipotesis alternatif
#
#     H1 : miu1 - miu2 != 0 (two-tailed)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik :
#
#     Daerah kritis :
#
# 5. Hitung nilai uji statistik

# %%
bulatan = gandum['bulatan']

bagian1 = bulatan.head(20)
bagian2 = bulatan.tail(20)

mean1 = bagian1.mean()
mean2 = bagian2.mean()

var1 = bagian1.var()
var2 = bagian2.var()

d0 = 0

zalpha = ptoz(alpha/2)
z = ztwotestmean(d0, mean1, mean2, var1, var2, bagian1.size, bagian2.size)

# %% [markdown]
# 6. Ambil keputusan

# %%
if z < zalpha or z > -zalpha:
  print("Null hypothesis ditolak")
  print("Rata-rata 20 baris pertama kolom bulatan tidak sama dengan 20 baris terakhirnya")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Rata-rata 20 baris pertama kolom bulatan tidak sama dengan 20 baris terakhirnya

# %% [markdown]
# ## D) Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : p1 - p2 - 0
# 2. Tentukan hipotesis alternatif
#
#     H1 : p1 - p2 > 0 (one-tailed)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik satu parameter populasi pengujian proporsi dua sampel one-tailed tes normal, z
#
#     Daerah kritis : z > zalpha
#
# 5. Hitung nilai uji statistik

# %%
ransum = gandum['ransum']

n1 = ransum.head(ransum.size // 2)
n2 = ransum.tail(ransum.size // 2)


x1 = n1.loc[n1 > 2]
x2 = n2.loc[n2 > 2]

p1 = x1.size/n1.size
p2 = x2.size/n2.size

p = (x1.size + x2.size)/(n1.size + n2.size)
q = 1 - p

pembilang = p1 - p2
penyebut = (p*q/n1.size) + (p*q/n2.size)
z = pembilang/math.sqrt(penyebut)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if z > zalpha:
  print("Null hypothesis ditolak")
  print("Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum")
else:
  print("Null hypothesis diterima")
# Out:
# Null hypothesis ditolak
# Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum

# %% [markdown]
# ## E) Bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya?

# %% [markdown]
# #### Langkah-Langkah
# 1. Tentukan hipotesis nol
#
#     H0 : var1 - var2 = 0
# 2. Tentukan hipotesis alternatif
#
#     H1 : var1 - var2 != 0 (two-tailed)
#
# 3. Tentukan tingkat signifkan
#
#     alpha = 0.05
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
#     Uji statistik : distribusi F
#
#     Daerah kritis : f < (1-aplha/2)f(v1,v2) or f > falpha/2(v1,v2)
# 5. Hitung nilai uji statistik

# %%
diameter = gandum['diameter']

awal = diameter.head(diameter.size // 2)
akhir = diameter.tail(diameter.size // 2)

awalvar = awal.var()
akhirvar = akhir.var()

if(awalvar > akhirvar):
  f = akhirvar/awalvar
else:
  f = awalvar/akhirvar

f1 = s.f.ppf(q=1-alpha/2, dfn=awal.size-1, dfd=akhir.size-1)
f2 = s.f.ppf(q=alpha/2, dfn=awal.size-1, dfd=akhir.size-1)

# %% [markdown]
# 6. Ambil Keputusan

# %%
if(f > f1 or f < f2):
  print("Null hypothesis ditolak")
else:
  print("Null hypothesis diterima")
  print("Bagian awal kolom Diameter tidak memiliki variansi yang sama dengan bagian akhirnya")
# Out:
# Null hypothesis diterima
# Bagian awal kolom Diameter tidak memiliki variansi yang sama dengan bagian akhirnya

# %% [markdown]
# # Test Korelasi

# %% [markdown]
# ### Daerah dengan Kelas

# %%
g.plot(kind='scatter', x='daerah', y='kelas')
a = g['daerah']
b = g['kelas']
a.corr(b)
# Out:
# -0.6027466517416662

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Sumbu Utama dengan Kelas

# %%
g.plot(kind='scatter', x='sumbu utama', y='kelas')
a = g['sumbu utama']
b = g['kelas']
a.corr(b)
# Out:
# -0.7130906104204593

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Sumbu Kecil dengan Kelas

# %%
g.plot(kind='scatter', x='sumbu kecil', y='kelas')
a = g['sumbu kecil']
b = g['kelas']
a.corr(b)
# Out:
# -0.15297517335535027

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Keunikan dengan Kelas

# %%
g.plot(kind='scatter', x='keunikan', y='kelas')
a = g['keunikan']
b = g['kelas']
a.corr(b)
# Out:
# -0.7304563686511922

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Area Bulatan dengan Kelas

# %%
g.plot(kind='scatter', x='area bulatan', y='kelas')
a = g['area bulatan']
b = g['kelas']
a.corr(b)
# Out:
# -0.6073125434153751

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Diameter dengan Kelas

# %%
g.plot(kind='scatter', x='diameter', y='kelas')
a = g['diameter']
b = g['kelas']
a.corr(b)
# Out:
# -0.6025356896618813

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Kadar Air dengan Kelas

# %%
g.plot(kind='scatter', x='kadar air', y='kelas')
a = g['kadar air']
b = g['kelas']
a.corr(b)
# Out:
# 0.13434422605727642

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Bulatan dengan Kelas

# %%
g.plot(kind='scatter', x='bulatan', y='kelas')
a = g['bulatan']
b = g['kelas']
a.corr(b)
# Out:
# 0.5450045317240076

# %% [markdown]
# ### Kesimpulan :

# %% [markdown]
# ### Ransum dengan Kelas

# %%
g.plot(kind='scatter', x='ransum', y='kelas')
a = g['ransum']
b = g['kelas']
a.corr(b)
# Out:
# -0.8399038681287493

# %% [markdown]
# ### Kesimpulan :
